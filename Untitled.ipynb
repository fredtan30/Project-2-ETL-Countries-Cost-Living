# %%
# %config Completer.use_jedi = False

import pandas as pd
from sqlalchemy import create_engine, Integer, String, Float
from config import *

# %%
quality_countries_file = "resources/quality_index_countries.csv"
quality_df = pd.read_csv(quality_countries_file)
quality_df.head()
# Out:
#        Country  Quality of Life Index  Purchasing Power Index  Safety Index  \
# 0      Denmark                 192.67                  100.88         74.90
# 1  Switzerland                 192.01                  119.53         78.40
# 2      Finland                 190.22                   99.93         76.68
# 3    Australia                 186.21                  107.31         58.64
# 4  Netherlands                 183.67                   90.73         72.38
#
#    Health Care Index  Cost of Living Index  Property Price to Income Ratio  \
# 0              80.00                 83.00                            7.45
# 1              72.44                122.40                            8.68
# 2              75.79                 70.29                            8.35
# 3              77.38                 73.54                            7.52
# 4              74.65                 73.75                            7.51
#
#    Traffic Commute Time Index  Pollution Index  Climate Index
# 0                       28.85            21.33          81.80
# 1                       29.09            22.39          79.24
# 2                       29.90            11.55          58.87
# 3                       34.73            23.46          92.70
# 4                       29.43            27.41          87.61

# %%
cost_living_file = "resources/cost_of_living_index.csv"
cost_living_df = pd.read_csv(cost_living_file)
cost_living_df.head()
# Out:
#        Country  Cost of Living Index  Rent Index  \
# 0  Switzerland                122.40       50.25
# 1       Norway                101.43       36.15
# 2      Iceland                100.48       46.95
# 3        Japan                 83.35       25.97
# 4      Denmark                 83.00       31.92
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                           87.89           120.27                  123.01
# 1                           70.21            91.14                  109.28
# 2                           74.88            86.89                  113.74
# 3                           55.90            81.82                   48.95
# 4                           58.57            61.74                  100.75
#
#    Local Purchasing Power Index
# 0                        119.53
# 1                         88.38
# 2                         79.44
# 3                         87.28
# 4                        100.88

# %%
properties_countries_file = "resources/properties_index_countries.csv"
properties_df = pd.read_csv(properties_countries_file)
properties_df.head()
# Out:
#      Country  Price To Income Ratio  Gross Rental Yield City Centre  \
# 0  Venezuela                 133.29                            6.22
# 1      Syria                  60.83                            2.71
# 2  Hong Kong                  47.46                            1.77
# 3   Cambodia                  42.33                            4.78
# 4      Kenya                  31.63                            2.15
#
#    Gross Rental Yield Outside of Centre  Price To Rent Ratio City Centre  \
# 0                                  6.45                            16.08
# 1                                  3.00                            36.93
# 2                                  1.83                            56.45
# 3                                  6.20                            20.93
# 4                                  4.07                            46.56
#
#    Price To Rent Ratio Outside Of City Centre  \
# 0                                       15.49
# 1                                       33.29
# 2                                       54.74
# 3                                       16.13
# 4                                       24.54
#
#    Mortgage As A Percentage Of Income  Affordability Index
# 0                             3025.03                 0.03
# 1                              662.83                 0.15
# 2                              303.35                 0.33
# 3                              479.45                 0.21
# 4                              472.19                 0.21

# %%
quality_cols = ["Country", "Quality of Life Index","Purchasing Power Index","Cost of Living Index", "Safety Index", "Health Care Index"
                , "Pollution Index","Property Price to Income Ratio"]
quality_transformed = quality_df[quality_cols].copy()

#Rename the column headers
quality_transformed = quality_transformed.rename(columns={"Country":"country", "Quality of Life Index":"quality_life_idx",
                                                          "Purchasing Power Index":"purchase_power_idx", "Safety Index":"safety_idx",
                                                          "Health Care Index":"health_care_idx", 
                "Cost of Living Index": "cost_living_idx", 
                                                          "Pollution Index":"pollution_idx",
                                                          "Property Price to Income Ratio":"property_price_income_ratio"})


#Set country as index
quality_transformed.set_index("country",inplace=True)

quality_transformed.head()
# Out:
#              quality_life_idx  purchase_power_idx  cost_living_idx  \
# country
# Denmark                192.67              100.88            83.00
# Switzerland            192.01              119.53           122.40
# Finland                190.22               99.93            70.29
# Australia              186.21              107.31            73.54
# Netherlands            183.67               90.73            73.75
#
#              safety_idx  health_care_idx  pollution_idx  \
# country
# Denmark           74.90            80.00          21.33
# Switzerland       78.40            72.44          22.39
# Finland           76.68            75.79          11.55
# Australia         58.64            77.38          23.46
# Netherlands       72.38            74.65          27.41
#
#              property_price_income_ratio
# country
# Denmark                             7.45
# Switzerland                         8.68
# Finland                             8.35
# Australia                           7.52
# Netherlands                         7.51

# %%
cost_living_cols = ["Country","Rent Index"]
cost_living_transformed = cost_living_df[cost_living_cols].copy()

#Rename the column headers
cost_living_transformed = cost_living_transformed.rename(columns={"Country":"country","Rent Index": "rent_idx"})


#Set country as index
cost_living_transformed.set_index("country",inplace=True)

cost_living_transformed.head()
# Out:
#              rent_idx
# country
# Switzerland     50.25
# Norway          36.15
# Iceland         46.95
# Japan           25.97
# Denmark         31.92

# %%
properties_cols = ["Country","Affordability Index"]
properties_transformed = properties_df[properties_cols].copy()

#Rename the column headers
properties_transformed = properties_transformed.rename(columns={"Country":"country","Affordability Index": "affordability_idx"})


#Set country as index
properties_transformed.set_index("country",inplace=True)

properties_transformed.head()
# Out:
#            affordability_idx
# country
# Venezuela               0.03
# Syria                   0.15
# Hong Kong               0.33
# Cambodia                0.21
# Kenya                   0.21

# %%
population_density_file = "resources/population_density_countries.csv"
population_density_df = pd.read_csv(population_density_file)
population_density_df.head()
# Out:
#   Rank Country (or dependent territory) Area km2 Area mi2 Population  \
# 0    –                            Macau     32.9       13   6,76,100
# 1    1                           Monaco     2.02     0.78     38,300
# 2    2                        Singapore    722.5      279  57,03,600
# 3    –                        Hong Kong    1,106      427  75,00,700
# 4    –                   Gibraltar (UK)      6.8      2.6     33,701
#
#   Density pop./km2 Density pop./mi2                Date  \
# 0           20,550           53,224  September 30, 2019
# 1           18,960           49,106   December 31, 2018
# 2            7,894           20,445        July 1, 2019
# 3            6,782           17,565   December 31, 2019
# 4            4,956           12,836        July 1, 2019
#
#              Population source
# 0  Official quarterly estimate
# 1            Official estimate
# 2            Official estimate
# 3            Official estimate
# 4                UN projection

# %%
population_cols = ["Country (or dependent territory)","Population"]
population_transformed = population_density_df[population_cols].copy()

#Rename the column headers
population_transformed = population_transformed.rename(columns={"Country (or dependent territory)":"country","Population": "population_density"})


#Set country as index
population_transformed.set_index("country",inplace=True)

population_transformed.head()
# Out:
#                population_density
# country
# Macau                    6,76,100
# Monaco                     38,300
# Singapore               57,03,600
# Hong Kong               75,00,700
# Gibraltar (UK)             33,701

# %%
URI = "postgres://jssxqibm:n9Q4br27p_f9Xj5qd5zDW3WjkQkIG9lE@rosie.db.elephantsql.com/jssxqibm" 

engine = create_engine(URI, echo=True)

quality_transformed.to_sql(
    'quality_of_life',
    engine,
    if_exists='replace',
    index=False,
    chunksize=500,
    dtype={
        "country": String(50),
        "quality_life_idx": Float,
        "purchase_power_idx": Float,
        "cost_living_idx": Float,
        "safety_idx":  Float,
        "health_care_idx": Float,
        "pollution_idx": Float,
        "property_price_income_ratio": Float

    }
)
                       
population_transformed.to_sql(
    'population_density',
    engine,
    if_exists='replace',
    index=False,
    chunksize=500,
    dtype={
        "country": String(50),
        "population_density": String(14),
    }
)
                       
properties_transformed.to_sql(
    'properties_affordability',
    engine,
    if_exists='replace',
    index=False,
    chunksize=500,
    dtype={
        "country": String(50),
        "affordability_idx": Float
    }
)
                       
cost_living_transformed.to_sql(
    'cost_living_rental_index',
    engine,
    if_exists='replace',
    index=False,
    chunksize=500,
    dtype={
        "country": String(50),
        "rent_idx": Float
    }
)
# Out:
# 2021-08-03 00:11:29,646 INFO sqlalchemy.engine.base.Engine select version()
# 2021-08-03 00:11:29,647 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:29,728 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2021-08-03 00:11:29,729 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:29,827 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-08-03 00:11:29,828 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:29,876 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-08-03 00:11:29,877 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:29,926 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2021-08-03 00:11:29,927 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:30,008 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-08-03 00:11:30,009 INFO sqlalchemy.engine.base.Engine {'name': 'quality_of_life'}
# 2021-08-03 00:11:30,155 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-08-03 00:11:30,156 INFO sqlalchemy.engine.base.Engine {'name': 'quality_of_life'}
# 2021-08-03 00:11:30,305 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-08-03 00:11:30,307 INFO sqlalchemy.engine.base.Engine {'schema': 'public'}
# 2021-08-03 00:11:30,398 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-08-03 00:11:30,399 INFO sqlalchemy.engine.base.Engine {'table_name': 'quality_of_life'}
# 2021-08-03 00:11:30,458 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               NULL as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-08-03 00:11:30,461 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403619}
# 2021-08-03 00:11:30,517 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-08-03 00:11:30,520 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:30,580 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-08-03 00:11:30,581 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:30,641 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-08-03 00:11:30,645 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403619}
# 2021-08-03 00:11:30,697 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-08-03 00:11:30,698 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403619}
# 2021-08-03 00:11:30,748 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2021-08-03 00:11:30,749 INFO sqlalchemy.engine.base.Engine {'table': 7403619}
# 2021-08-03 00:11:30,797 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2021-08-03 00:11:30,798 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403619}
# 2021-08-03 00:11:30,868 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-08-03 00:11:30,869 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403619}
# 2021-08-03 00:11:30,916 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2021-08-03 00:11:30,917 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403619}
# 2021-08-03 00:11:30,976 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-08-03 00:11:30,978 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403619}
# 2021-08-03 00:11:31,077 INFO sqlalchemy.engine.base.Engine
# DROP TABLE quality_of_life
# 2021-08-03 00:11:31,080 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:31,167 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:31,221 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE quality_of_life (
# 	quality_life_idx FLOAT,
# 	purchase_power_idx FLOAT,
# 	cost_living_idx FLOAT,
# 	safety_idx FLOAT,
# 	health_care_idx FLOAT,
# 	pollution_idx FLOAT,
# 	property_price_income_ratio FLOAT
# )
#
#
# 2021-08-03 00:11:31,222 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:31,305 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:31,359 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-03 00:11:31,361 INFO sqlalchemy.engine.base.Engine INSERT INTO quality_of_life (quality_life_idx, purchase_power_idx, cost_living_idx, safety_idx, health_care_idx, pollution_idx, property_price_income_ratio) VALUES (%(quality_life_idx)s, %(purchase_power_idx)s, %(cost_living_idx)s, %(safety_idx)s, %(health_care_idx)s, %(pollution_idx)s, %(property_price_income_ratio)s)
# 2021-08-03 00:11:31,362 INFO sqlalchemy.engine.base.Engine ({'quality_life_idx': 192.67, 'purchase_power_idx': 100.88, 'cost_living_idx': 83.0, 'safety_idx': 74.9, 'health_care_idx': 80.0, 'pollution_idx': 21.33, 'property_price_income_ratio': 7.45}, {'quality_life_idx': 192.01, 'purchase_power_idx': 119.53, 'cost_living_idx': 122.4, 'safety_idx': 78.4, 'health_care_idx': 72.44, 'pollution_idx': 22.39, 'property_price_income_ratio': 8.68}, {'quality_life_idx': 190.22, 'purchase_power_idx': 99.93, 'cost_living_idx': 70.29, 'safety_idx': 76.68, 'health_care_idx': 75.79, 'pollution_idx': 11.55, 'property_price_income_ratio': 8.35}, {'quality_life_idx': 186.21, 'purchase_power_idx': 107.31, 'cost_living_idx': 73.54, 'safety_idx': 58.64, 'health_care_idx': 77.38, 'pollution_idx': 23.46, 'property_price_income_ratio': 7.52}, {'quality_life_idx': 183.67, 'purchase_power_idx': 90.73, 'cost_living_idx': 73.75, 'safety_idx': 72.38, 'health_care_idx': 74.65, 'pollution_idx': 27.41, 'property_price_income_ratio': 7.51}, {'quality_life_idx': 182.5, 'purchase_power_idx': 82.38, 'cost_living_idx': 70.38, 'safety_idx': 76.27, 'health_care_idx': 78.73, 'pollution_idx': 22.19, 'property_price_income_ratio': 10.88}, {'quality_life_idx': 181.75, 'purchase_power_idx': 79.44, 'cost_living_idx': 100.48, 'safety_idx': 76.64, 'health_care_idx': 65.92, 'pollution_idx': 16.21, 'property_price_income_ratio': 6.74}, {'quality_life_idx': 181.02, 'purchase_power_idx': 92.66, 'cost_living_idx': 72.53, 'safety_idx': 59.07, 'health_care_idx': 73.81, 'pollution_idx': 23.4, 'property_price_income_ratio': 8.52}  ... displaying 10 of 80 total bound parameter sets ...  {'quality_life_idx': 70.03, 'purchase_power_idx': 33.21, 'cost_living_idx': 32.25, 'safety_idx': 36.06, 'health_care_idx': 42.8, 'pollution_idx': 86.21, 'property_price_income_ratio': 13.1}, {'quality_life_idx': 55.65, 'purchase_power_idx': 13.52, 'cost_living_idx': 31.0, 'safety_idx': 36.23, 'health_care_idx': 51.59, 'pollution_idx': 87.63, 'property_price_income_ratio': 16.7})
# 2021-08-03 00:11:35,595 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:35,641 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-08-03 00:11:35,642 INFO sqlalchemy.engine.base.Engine {'name': 'population_density'}
# 2021-08-03 00:11:35,785 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-08-03 00:11:35,786 INFO sqlalchemy.engine.base.Engine {'name': 'population_density'}
# 2021-08-03 00:11:35,926 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-08-03 00:11:35,927 INFO sqlalchemy.engine.base.Engine {'schema': 'public'}
# 2021-08-03 00:11:36,021 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-08-03 00:11:36,022 INFO sqlalchemy.engine.base.Engine {'table_name': 'population_density'}
# 2021-08-03 00:11:36,077 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               NULL as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-08-03 00:11:36,078 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403622}
# 2021-08-03 00:11:36,128 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-08-03 00:11:36,130 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:36,177 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-08-03 00:11:36,178 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:36,238 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-08-03 00:11:36,239 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403622}
# 2021-08-03 00:11:36,301 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-08-03 00:11:36,303 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403622}
# 2021-08-03 00:11:36,355 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
# 2021-08-03 00:11:36,356 INFO sqlalchemy.engine.base.Engine {'table': 7403622}
# 2021-08-03 00:11:36,406 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2021-08-03 00:11:36,407 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403622}
# 2021-08-03 00:11:36,469 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-08-03 00:11:36,471 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403622}
# 2021-08-03 00:11:36,527 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2021-08-03 00:11:36,528 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403622}
# 2021-08-03 00:11:36,586 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-08-03 00:11:36,587 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403622}
# 2021-08-03 00:11:36,685 INFO sqlalchemy.engine.base.Engine
# DROP TABLE population_density
# 2021-08-03 00:11:36,686 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:36,767 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:36,811 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE population_density (
# 	population_density VARCHAR(14)
# )
#
#
# 2021-08-03 00:11:36,812 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:36,887 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:36,927 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-03 00:11:36,929 INFO sqlalchemy.engine.base.Engine INSERT INTO population_density (population_density) VALUES (%(population_density)s)
# 2021-08-03 00:11:36,930 INFO sqlalchemy.engine.base.Engine ({'population_density': '6,76,100'}, {'population_density': '38,300'}, {'population_density': '57,03,600'}, {'population_density': '75,00,700'}, {'population_density': '33,701'}, {'population_density': '1,000'}, {'population_density': '15,43,300'}, {'population_density': '4,93,559'}  ... displaying 10 of 251 total bound parameter sets ...  {'population_density': '2,655'}, {'population_density': '55,877'})
# 2021-08-03 00:11:47,986 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:48,033 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-08-03 00:11:48,034 INFO sqlalchemy.engine.base.Engine {'name': 'properties_affordability'}
# 2021-08-03 00:11:48,176 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-08-03 00:11:48,176 INFO sqlalchemy.engine.base.Engine {'name': 'properties_affordability'}
# 2021-08-03 00:11:48,315 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-08-03 00:11:48,316 INFO sqlalchemy.engine.base.Engine {'schema': 'public'}
# 2021-08-03 00:11:48,406 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-08-03 00:11:48,407 INFO sqlalchemy.engine.base.Engine {'table_name': 'properties_affordability'}
# 2021-08-03 00:11:48,465 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               NULL as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-08-03 00:11:48,465 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403625}
# 2021-08-03 00:11:48,528 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-08-03 00:11:48,529 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:48,587 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-08-03 00:11:48,588 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:48,647 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-08-03 00:11:48,648 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403625}
# 2021-08-03 00:11:48,706 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-08-03 00:11:48,708 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403625}
# 2021-08-03 00:11:48,756 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2021-08-03 00:11:48,757 INFO sqlalchemy.engine.base.Engine {'table': 7403625}
# 2021-08-03 00:11:48,812 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2021-08-03 00:11:48,813 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403625}
# 2021-08-03 00:11:48,868 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-08-03 00:11:48,868 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403625}
# 2021-08-03 00:11:48,927 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2021-08-03 00:11:48,928 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403625}
# 2021-08-03 00:11:48,988 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-08-03 00:11:48,989 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403625}
# 2021-08-03 00:11:49,085 INFO sqlalchemy.engine.base.Engine
# DROP TABLE properties_affordability
# 2021-08-03 00:11:49,086 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:49,176 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:49,251 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE properties_affordability (
# 	affordability_idx FLOAT
# )
#
#
# 2021-08-03 00:11:49,251 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:49,357 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:49,397 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-03 00:11:49,399 INFO sqlalchemy.engine.base.Engine INSERT INTO properties_affordability (affordability_idx) VALUES (%(affordability_idx)s)
# 2021-08-03 00:11:49,399 INFO sqlalchemy.engine.base.Engine ({'affordability_idx': 0.03}, {'affordability_idx': 0.15}, {'affordability_idx': 0.33}, {'affordability_idx': 0.21}, {'affordability_idx': 0.21}, {'affordability_idx': 0.21}, {'affordability_idx': 0.43}, {'affordability_idx': 0.19}  ... displaying 10 of 104 total bound parameter sets ...  {'affordability_idx': 3.79}, {'affordability_idx': 4.85})
# 2021-08-03 00:11:54,096 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:54,141 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-08-03 00:11:54,144 INFO sqlalchemy.engine.base.Engine {'name': 'cost_living_rental_index'}
# 2021-08-03 00:11:54,284 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2021-08-03 00:11:54,285 INFO sqlalchemy.engine.base.Engine {'name': 'cost_living_rental_index'}
# 2021-08-03 00:11:54,425 INFO sqlalchemy.engine.base.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2021-08-03 00:11:54,426 INFO sqlalchemy.engine.base.Engine {'schema': 'public'}
# 2021-08-03 00:11:54,527 INFO sqlalchemy.engine.base.Engine
#             SELECT c.oid
#             FROM pg_catalog.pg_class c
#             LEFT JOIN pg_catalog.pg_namespace n ON n.oid = c.relnamespace
#             WHERE (pg_catalog.pg_table_is_visible(c.oid))
#             AND c.relname = %(table_name)s AND c.relkind in
#             ('r', 'v', 'm', 'f', 'p')
#
# 2021-08-03 00:11:54,528 INFO sqlalchemy.engine.base.Engine {'table_name': 'cost_living_rental_index'}
# 2021-08-03 00:11:54,587 INFO sqlalchemy.engine.base.Engine
#             SELECT a.attname,
#               pg_catalog.format_type(a.atttypid, a.atttypmod),
#               (SELECT pg_catalog.pg_get_expr(d.adbin, d.adrelid)
#                 FROM pg_catalog.pg_attrdef d
#                WHERE d.adrelid = a.attrelid AND d.adnum = a.attnum
#                AND a.atthasdef)
#               AS DEFAULT,
#               a.attnotnull, a.attnum, a.attrelid as table_oid,
#               pgd.description as comment,
#               NULL as generated
#             FROM pg_catalog.pg_attribute a
#             LEFT JOIN pg_catalog.pg_description pgd ON (
#                 pgd.objoid = a.attrelid AND pgd.objsubid = a.attnum)
#             WHERE a.attrelid = %(table_oid)s
#             AND a.attnum > 0 AND NOT a.attisdropped
#             ORDER BY a.attnum
#
# 2021-08-03 00:11:54,587 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403628}
# 2021-08-03 00:11:54,636 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                pg_catalog.format_type(t.typbasetype, t.typtypmod) as "attype",
#                not t.typnotnull as "nullable",
#                t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema"
#             FROM pg_catalog.pg_type t
#                LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#             WHERE t.typtype = 'd'
#
# 2021-08-03 00:11:54,636 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:54,696 INFO sqlalchemy.engine.base.Engine
#             SELECT t.typname as "name",
#                -- no enum defaults in 8.4 at least
#                -- t.typdefault as "default",
#                pg_catalog.pg_type_is_visible(t.oid) as "visible",
#                n.nspname as "schema",
#                e.enumlabel as "label"
#             FROM pg_catalog.pg_type t
#                  LEFT JOIN pg_catalog.pg_namespace n ON n.oid = t.typnamespace
#                  LEFT JOIN pg_catalog.pg_enum e ON t.oid = e.enumtypid
#             WHERE t.typtype = 'e'
#         ORDER BY "schema", "name", e.oid
# 2021-08-03 00:11:54,696 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:54,745 INFO sqlalchemy.engine.base.Engine
#                 SELECT a.attname
#                 FROM pg_attribute a JOIN (
#                     SELECT unnest(ix.indkey) attnum,
#                            generate_subscripts(ix.indkey, 1) ord
#                     FROM pg_index ix
#                     WHERE ix.indrelid = %(table_oid)s AND ix.indisprimary
#                     ) k ON a.attnum=k.attnum
#                 WHERE a.attrelid = %(table_oid)s
#                 ORDER BY k.ord
#
# 2021-08-03 00:11:54,746 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403628}
# 2021-08-03 00:11:54,797 INFO sqlalchemy.engine.base.Engine
#         SELECT conname
#            FROM  pg_catalog.pg_constraint r
#            WHERE r.conrelid = %(table_oid)s AND r.contype = 'p'
#            ORDER BY 1
#
# 2021-08-03 00:11:54,798 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403628}
# 2021-08-03 00:11:54,856 INFO sqlalchemy.engine.base.Engine
#           SELECT r.conname,
#                 pg_catalog.pg_get_constraintdef(r.oid, true) as condef,
#                 n.nspname as conschema
#           FROM  pg_catalog.pg_constraint r,
#                 pg_namespace n,
#                 pg_class c
#
#           WHERE r.conrelid = %(table)s AND
#                 r.contype = 'f' AND
#                 c.oid = confrelid AND
#                 n.oid = c.relnamespace
#           ORDER BY 1
#
# 2021-08-03 00:11:54,856 INFO sqlalchemy.engine.base.Engine {'table': 7403628}
# 2021-08-03 00:11:54,905 INFO sqlalchemy.engine.base.Engine
#               SELECT
#                   i.relname as relname,
#                   ix.indisunique, ix.indexprs, ix.indpred,
#                   a.attname, a.attnum, c.conrelid, ix.indkey::varchar,
#                   ix.indoption::varchar, i.reloptions, am.amname,
#                   ix.indnkeyatts as indnkeyatts
#               FROM
#                   pg_class t
#                         join pg_index ix on t.oid = ix.indrelid
#                         join pg_class i on i.oid = ix.indexrelid
#                         left outer join
#                             pg_attribute a
#                             on t.oid = a.attrelid and a.attnum = ANY(ix.indkey)
#                         left outer join
#                             pg_constraint c
#                             on (ix.indrelid = c.conrelid and
#                                 ix.indexrelid = c.conindid and
#                                 c.contype in ('p', 'u', 'x'))
#                         left outer join
#                             pg_am am
#                             on i.relam = am.oid
#               WHERE
#                   t.relkind IN ('r', 'v', 'f', 'm', 'p')
#                   and t.oid = %(table_oid)s
#                   and ix.indisprimary = 'f'
#               ORDER BY
#                   t.relname,
#                   i.relname
#
# 2021-08-03 00:11:54,906 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403628}
# 2021-08-03 00:11:54,968 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 cons.conkey as key,
#                 a.attnum as col_num,
#                 a.attname as col_name
#             FROM
#                 pg_catalog.pg_constraint cons
#                 join pg_attribute a
#                   on cons.conrelid = a.attrelid AND
#                     a.attnum = ANY(cons.conkey)
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'u'
#
# 2021-08-03 00:11:54,968 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403628}
# 2021-08-03 00:11:55,019 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 cons.conname as name,
#                 pg_get_constraintdef(cons.oid) as src
#             FROM
#                 pg_catalog.pg_constraint cons
#             WHERE
#                 cons.conrelid = %(table_oid)s AND
#                 cons.contype = 'c'
#
# 2021-08-03 00:11:55,020 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403628}
# 2021-08-03 00:11:55,076 INFO sqlalchemy.engine.base.Engine
#             SELECT
#                 pgd.description as table_comment
#             FROM
#                 pg_catalog.pg_description pgd
#             WHERE
#                 pgd.objsubid = 0 AND
#                 pgd.objoid = %(table_oid)s
#
# 2021-08-03 00:11:55,077 INFO sqlalchemy.engine.base.Engine {'table_oid': 7403628}
# 2021-08-03 00:11:55,185 INFO sqlalchemy.engine.base.Engine
# DROP TABLE cost_living_rental_index
# 2021-08-03 00:11:55,187 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:55,267 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:55,311 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE cost_living_rental_index (
# 	rent_idx FLOAT
# )
#
#
# 2021-08-03 00:11:55,312 INFO sqlalchemy.engine.base.Engine {}
# 2021-08-03 00:11:55,396 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-03 00:11:55,450 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-03 00:11:55,452 INFO sqlalchemy.engine.base.Engine INSERT INTO cost_living_rental_index (rent_idx) VALUES (%(rent_idx)s)
# 2021-08-03 00:11:55,454 INFO sqlalchemy.engine.base.Engine ({'rent_idx': 50.25}, {'rent_idx': 36.15}, {'rent_idx': 46.95}, {'rent_idx': 25.97}, {'rent_idx': 31.92}, {'rent_idx': 36.36}, {'rent_idx': 54.92}, {'rent_idx': 31.33}  ... displaying 10 of 132 total bound parameter sets ...  {'rent_idx': 4.03}, {'rent_idx': 4.59})
# 2021-08-03 00:12:01,306 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# queryJoin = 'SELECT quality_of_life.country, quality_of_life.quality_life_idx, quality_of_life.purchase_power_idx, quality_of_life.purchase_power_idx, quality_of_life.safety_idx, quality_of_life.health_care_idx,quality_of_life.cost_living_index, cost_living.rent_index, quality_of_life.pollution_index, properties_affordability.affordability_idx, cost_living_rental_index.rent_idx FROM quality_of_life, population_density, properties_affordability, cost_living_rental_index WHERE quality_of_life.country = properties_affordability.country AND quality_of_life.country = cost_living_rental_index.country AND quality_of_life.country = population_density.country'

joined_table_df = pd.read_sql_query("SELECT quality_of_life.country, quality_of_life.quality_life_idx, quality_of_life.purchase_power_idx, quality_of_life.purchase_power_idx, quality_of_life.safety_idx, quality_of_life.health_care_idx,quality_of_life.cost_living_index, cost_living.rent_index, quality_of_life.pollution_index, properties_affordability.affordability_idx, cost_living_rental_index.rent_idx FROM quality_of_life, population_density, properties_affordability, cost_living_rental_index WHERE quality_of_life.country = properties_affordability.country AND quality_of_life.country = cost_living_rental_index.country AND quality_of_life.country = population_density.country;", con=engine)

joined_table_df.head()
# Out:
# 2021-08-03 00:18:15,714 INFO sqlalchemy.engine.base.OptionEngine SELECT quality_of_life.country, quality_of_life.quality_life_idx, quality_of_life.purchase_power_idx, quality_of_life.purchase_power_idx, quality_of_life.safety_idx, quality_of_life.health_care_idx,quality_of_life.cost_living_index, cost_living.rent_index, quality_of_life.pollution_index, properties_affordability.affordability_idx, cost_living_rental_index.rent_idx FROM quality_of_life, population_density, properties_affordability, cost_living_rental_index WHERE quality_of_life.country = properties_affordability.country AND quality_of_life.country = cost_living_rental_index.country AND quality_of_life.country = population_density.country;
# 2021-08-03 00:18:15,717 INFO sqlalchemy.engine.base.OptionEngine {}
# 2021-08-03 00:18:15,813 INFO sqlalchemy.engine.base.OptionEngine ROLLBACK
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1265                 if not evt_handled:
# -> 1266                     self.dialect.do_execute_no_params(
#    1267                         cursor, statement, context
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute_no_params(self, cursor, statement, context)
#     595     def do_execute_no_params(self, cursor, statement, context=None):
# --> 596         cursor.execute(statement)
#     597
#
# UndefinedColumn: column quality_of_life.country does not exist
# LINE 1: SELECT quality_of_life.country, quality_of_life.quality_life...
#                ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-27-90257784c942> in <module>
#       1 # queryJoin = 'SELECT quality_of_life.country, quality_of_life.quality_life_idx, quality_of_life.purchase_power_idx, quality_of_life.purchase_power_idx, quality_of_life.safety_idx, quality_of_life.health_care_idx,quality_of_life.cost_living_index, cost_living.rent_index, quality_of_life.pollution_index, properties_affordability.affordability_idx, cost_living_rental_index.rent_idx FROM quality_of_life, population_density, properties_affordability, cost_living_rental_index WHERE quality_of_life.country = properties_affordability.country AND quality_of_life.country = cost_living_rental_index.country AND quality_of_life.country = population_density.country'
#       2
# ----> 3 joined_table_df = pd.read_sql_query("SELECT quality_of_life.country, quality_of_life.quality_life_idx, quality_of_life.purchase_power_idx, quality_of_life.purchase_power_idx, quality_of_life.safety_idx, quality_of_life.health_care_idx,quality_of_life.cost_living_index, cost_living.rent_index, quality_of_life.pollution_index, properties_affordability.affordability_idx, cost_living_rental_index.rent_idx FROM quality_of_life, population_density, properties_affordability, cost_living_rental_index WHERE quality_of_life.country = properties_affordability.country AND quality_of_life.country = cost_living_rental_index.country AND quality_of_life.country = population_density.country;", con=engine)
#       4
#       5 joined_table_df.head()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     375     """
#     376     pandas_sql = pandasSQL_builder(con)
# --> 377     return pandas_sql.read_query(
#     378         sql,
#     379         index_col=index_col,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1293         args = _convert_params(sql, params)
#    1294
# -> 1295         result = self.execute(*args)
#    1296         columns = result.keys()
#    1297
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1159     def execute(self, *args, **kwargs):
#    1160         """Simple passthrough to SQLAlchemy connectable"""
# -> 1161         return self.connectable.execution_options(no_parameters=True).execute(
#    1162             *args, **kwargs
#    1163         )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2233
#    2234         connection = self._contextual_connect(close_with_result=True)
# -> 2235         return connection.execute(statement, *multiparams, **params)
#    2236
#    2237     def scalar(self, statement, *multiparams, **params):
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1001         """
#    1002         if isinstance(object_, util.string_types[0]):
# -> 1003             return self._execute_text(object_, multiparams, params)
#    1004         try:
#    1005             meth = object_._execute_on_connection
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1170         dialect = self.dialect
#    1171         parameters = _distill_params(multiparams, params)
# -> 1172         ret = self._execute_context(
#    1173             dialect,
#    1174             dialect.execution_ctx_cls._init_statement,
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1264                             break
#    1265                 if not evt_handled:
# -> 1266                     self.dialect.do_execute_no_params(
#    1267                         cursor, statement, context
#    1268                     )
#
# /opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute_no_params(self, cursor, statement, context)
#     594
#     595     def do_execute_no_params(self, cursor, statement, context=None):
# --> 596         cursor.execute(statement)
#     597
#     598     def is_disconnect(self, e, connection, cursor):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column quality_of_life.country does not exist
# LINE 1: SELECT quality_of_life.country, quality_of_life.quality_life...
#                ^
#
# [SQL: SELECT quality_of_life.country, quality_of_life.quality_life_idx, quality_of_life.purchase_power_idx, quality_of_life.purchase_power_idx, quality_of_life.safety_idx, quality_of_life.health_care_idx,quality_of_life.cost_living_index, cost_living.rent_index, quality_of_life.pollution_index, properties_affordability.affordability_idx, cost_living_rental_index.rent_idx FROM quality_of_life, population_density, properties_affordability, cost_living_rental_index WHERE quality_of_life.country = properties_affordability.country AND quality_of_life.country = cost_living_rental_index.country AND quality_of_life.country = population_density.country;]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
pd.read_sql_query('select * from quality_countries;', con=engine).head()
